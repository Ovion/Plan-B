# %%
import pandas as pd
import re
import random
import numpy as np

# %%
df = pd.read_csv('bicicletas/AccidentesBicicletas_2017.csv', encoding='latin_1',sep = ';')

# %%
def minor_change_2017(df):
    dict_rename = {
        'Nº VICTIMAS *':'* Nº VICTIMAS'
    }
    df.rename(columns=dict_rename, inplace=True)
    return df

df = minor_change_2017(df)

# %%
df.head()
# Out:
#         FECHA     RANGO HORARIO DIA SEMANA                        DISTRITO  \
# 0  01/01/2017    DE 6:00 A 6:59    DOMINGO  ARGANZUELA
# 1  02/01/2017  DE 21:00 A 21:59      LUNES  SAN BLAS
# 2  03/01/2017  DE 19:00 A 19:59     MARTES  CENTRO
# 3  04/01/2017  DE 21:00 A 21:59  MIERCOLES  CENTRO
# 4  05/01/2017    DE 8:00 A 8:59     JUEVES  MONCLOA-ARAVACA
#
#                                      LUGAR ACCIDENTE   Nº  Nº PARTE  \
# 0  CALLE DE TOLEDO NUM                           ...  120   2017/88
# 1  CALLE DE MEQUINENZA NUM                       ...   14   2017/70
# 2  CALLE DE LA ESCALINATA NUM                    ...    8  2017/307
# 3  CALLE DE LA CAVA DE SAN MIGUEL NUM            ...   13  2017/124
# 4  PUENTE DE LOS FRANCESES                       ...    0  2017/206
#
#   CPFA Granizo CPFA Hielo CPFA Lluvia  ... CPSV Grava Suelta CPSV Hielo  \
# 0           NO         NO          NO  ...                NO         NO
# 1           NO         NO          NO  ...                NO         NO
# 2           NO         NO          NO  ...                NO         NO
# 3           NO         NO          NO  ...                NO         NO
# 4           NO         NO          NO  ...                NO         NO
#
#   CPSV Seca Y Limpia * Nº VICTIMAS                            TIPO ACCIDENTE  \
# 0                 SI           1.0  CHOQUE CON OBJETO FIJO
# 1                 SI           1.0  CAÍDA BICICLETA
# 2                 SI           1.0  CAÍDA BICICLETA
# 3                 NO           1.0  CAÍDA BICICLETA
# 4                 NO           1.0  CAÍDA BICICLETA
#
#                               Tipo Vehiculo TIPO PERSONA    SEXO  \
# 0  BICICLETA                                   CONDUCTOR   MUJER
# 1  BICICLETA                                   CONDUCTOR  HOMBRE
# 2  BICICLETA                                   CONDUCTOR  HOMBRE
# 3  BICICLETA                                   CONDUCTOR  HOMBRE
# 4  BICICLETA                                   CONDUCTOR  HOMBRE
#
#                                   LESIVIDAD       Tramo Edad
# 0  HG                                        DE 21 A 24 AÑOS
# 1  HL                                        DE 25 A 29 AÑOS
# 2  HL                                        DE 18 A 20 AÑOS
# 3  HL                                        DE 30 A 34 ANOS
# 4  HL                                        DE 45 A 49 AÑOS
#
# [5 rows x 26 columns]

# %%
def change_cols_17_18(df):
    dict_cols = {
        'FECHA':'dia',
        'DISTRITO':'distrito', 'LUGAR ACCIDENTE': 'calle', 'Nº': 'num',
        'TIPO ACCIDENTE':'tipo_accidente', 'LESIVIDAD': 'lesividad',
        'CPFA Granizo':'Granizo', 'CPFA Hielo': 'Hielo', 'CPFA Lluvia': 'Lluvia',
        'CPFA Niebla': 'Niebla', 'CPFA Seco': 'Despejado', 'CPFA Nieve': 'Nieve',
    }
    to_drop = ['Nº PARTE','CPSV Seca Y Limpia', 'CPSV Mojada', 'CPSV Aceite', 'CPSV Barro', 'CPSV Grava Suelta', 'CPSV Hielo', '* Nº VICTIMAS', 'Tipo Vehiculo', 'TIPO PERSONA', 'SEXO', 'Tramo Edad']
    df.rename(columns=dict_cols, inplace = True)
    df.drop(to_drop, axis=1, inplace=True)
    
    return df

df = change_cols_17_18(df)

# %%
    
def create_weather_17_18 (df):
    lst_w = list(df[df.columns[6:12]])
    print(lst_w)
    for e in lst_w:
        df[e] = df[e].apply(lambda x: '' if (x=='NO') else e)
    df['meteo'] = df[lst_w].sum(axis=1)
    df.drop(lst_w, axis=1, inplace=True)
    return df
    
df = create_weather_17_18(df)
# Out:
# ['Granizo', 'Hielo', 'Lluvia', 'Niebla', 'Despejado', 'Nieve']

# %%
df.head()
# Out:
#           dia     RANGO HORARIO DIA SEMANA                        distrito  \
# 0  01/01/2017    DE 6:00 A 6:59    DOMINGO  ARGANZUELA
# 1  02/01/2017  DE 21:00 A 21:59      LUNES  SAN BLAS
# 2  03/01/2017  DE 19:00 A 19:59     MARTES  CENTRO
# 3  04/01/2017  DE 21:00 A 21:59  MIERCOLES  CENTRO
# 4  05/01/2017    DE 8:00 A 8:59     JUEVES  MONCLOA-ARAVACA
#
#                                                calle  num  \
# 0  CALLE DE TOLEDO NUM                           ...  120
# 1  CALLE DE MEQUINENZA NUM                       ...   14
# 2  CALLE DE LA ESCALINATA NUM                    ...    8
# 3  CALLE DE LA CAVA DE SAN MIGUEL NUM            ...   13
# 4  PUENTE DE LOS FRANCESES                       ...    0
#
#                              tipo_accidente  \
# 0  CHOQUE CON OBJETO FIJO
# 1  CAÍDA BICICLETA
# 2  CAÍDA BICICLETA
# 3  CAÍDA BICICLETA
# 4  CAÍDA BICICLETA
#
#                                   lesividad      meteo
# 0  HG                                        Despejado
# 1  HL                                        Despejado
# 2  HL                                        Despejado
# 3  HL                                           Niebla
# 4  HL                                           Niebla

# %%
df.meteo.value_counts()
# Out:
# Despejado                                 717
# Lluvia                                     32
# Niebla                                      5
# GranizoHieloLluviaNieblaDespejadoNieve      1
# Hielo                                       1
# NieblaDespejado                             1
# Name: meteo, dtype: int64

# %%
def refactor_meteo_17_18 (values):
    dict_meteo = {
        r'Granizo': 'Granizo',
        r'Hielo': 'Nieve',
        r'Nieve': 'Nieve',
        r'Lluvia': 'Lluvia',
        r'Niebla': 'Niebla',}
    for k,v in dict_meteo.items():
        if re.match(k, values):
            return v
    return 'Despejado'

df.meteo = df.meteo.apply(lambda x: refactor_meteo_17_18(x))

# %%
df.meteo.value_counts()
# Out:
# Despejado    717
# Lluvia        32
# Niebla         6
# Nieve          1
# Granizo        1
# Name: meteo, dtype: int64

# %%
def create_date(df):
    df['fecha'] = df.dia+' '+df.hora
    df['fecha'] = pd.to_datetime(df['fecha'], dayfirst=True)
    df['fecha'] = df['fecha'].dt.round('H')
    df.drop(['dia', 'hora'], axis=1, inplace = True)
    return df

# %%
def create_date_17_18(df):
    df['hora'] = df['RANGO HORARIO'].str.extract(r'(\d[\d]?:\d+\s)')
    create_date(df)
    df.drop(['RANGO HORARIO', 'DIA SEMANA'], axis=1, inplace=True)
    return df

df = create_date_17_18(df)

# %%
df.head()
# Out:
#                          distrito  \
# 0  ARGANZUELA
# 1  SAN BLAS
# 2  CENTRO
# 3  CENTRO
# 4  MONCLOA-ARAVACA
#
#                                                calle  num  \
# 0  CALLE DE TOLEDO NUM                           ...  120
# 1  CALLE DE MEQUINENZA NUM                       ...   14
# 2  CALLE DE LA ESCALINATA NUM                    ...    8
# 3  CALLE DE LA CAVA DE SAN MIGUEL NUM            ...   13
# 4  PUENTE DE LOS FRANCESES                       ...    0
#
#                              tipo_accidente  \
# 0  CHOQUE CON OBJETO FIJO
# 1  CAÍDA BICICLETA
# 2  CAÍDA BICICLETA
# 3  CAÍDA BICICLETA
# 4  CAÍDA BICICLETA
#
#                                   lesividad      meteo               fecha
# 0  HG                                        Despejado 2017-01-01 06:00:00
# 1  HL                                        Despejado 2017-01-02 21:00:00
# 2  HL                                        Despejado 2017-01-03 19:00:00
# 3  HL                                           Niebla 2017-01-04 21:00:00
# 4  HL                                           Niebla 2017-01-05 08:00:00

# %%
df.shape
# Out:
# (757, 7)

# %%
df.dropna(inplace=True)

# %%
df.shape
# Out:
# (756, 7)

# %%
def create_dir(df):
    df.num = df.num.apply(lambda x: x.strip())
    df.num = df.num.apply(lambda x: '-' if x=='0' else x)
    df.loc[(df.num == '-'), 'num']=''
    df['direccion'] = df.calle+' '+df.num
    df.direccion = df.direccion.apply(lambda x: x.strip())
    df.drop(['calle', 'num'], axis=1, inplace = True)
    return df

df = create_dir(df)

# %%
def change_accident(values):
    dict_accidente = {
        r'caída':'Caida',
        r'colisión':'Colision',
        r'alcance':'Colision',
        r'atropello':'Imprudencia',
        r'choque':'Imprudencia'}
    for k, v in dict_accidente.items():
        if re.match(k, values.lower()):
            return v
    return 'Otro'

df.tipo_accidente = df.tipo_accidente.apply(lambda x: change_accident(x))

# %%
df.head()
# Out:
#                          distrito tipo_accidente  \
# 0  ARGANZUELA                        Imprudencia
# 1  SAN BLAS                                Caida
# 2  CENTRO                                  Caida
# 3  CENTRO                                  Caida
# 4  MONCLOA-ARAVACA                         Caida
#
#                                   lesividad      meteo               fecha  \
# 0  HG                                        Despejado 2017-01-01 06:00:00
# 1  HL                                        Despejado 2017-01-02 21:00:00
# 2  HL                                        Despejado 2017-01-03 19:00:00
# 3  HL                                           Niebla 2017-01-04 21:00:00
# 4  HL                                           Niebla 2017-01-05 08:00:00
#
#                                            direccion
# 0  CALLE DE TOLEDO NUM                           ...
# 1  CALLE DE MEQUINENZA NUM                       ...
# 2  CALLE DE LA ESCALINATA NUM                    ...
# 3  CALLE DE LA CAVA DE SAN MIGUEL NUM            ...
# 4                            PUENTE DE LOS FRANCESES

# %%
df.lesividad.value_counts(dropna=False)
# Out:
# HL                                          628
# HG                                           60
# IL                                           59
# NO ASIGNADA                                   8
# MT                                            1
# Name: lesividad, dtype: int64

# %%
def change_injury_17_18(values):
    dict_injury = {
        'IL':'Moderada',
        'HG':'Grave',
        'MT':'Fallecido',
        'HL':'Leve', 'NO ASIGNADA':'Leve'}
    return dict_injury[values]

df.lesividad = df.lesividad.apply(lambda x: change_injury_17_18(x.strip()))

# %%
df.head()
# Out:
#                          distrito tipo_accidente lesividad      meteo  \
# 0  ARGANZUELA                        Imprudencia     Grave  Despejado
# 1  SAN BLAS                                Caida      Leve  Despejado
# 2  CENTRO                                  Caida      Leve  Despejado
# 3  CENTRO                                  Caida      Leve     Niebla
# 4  MONCLOA-ARAVACA                         Caida      Leve     Niebla
#
#                 fecha                                          direccion
# 0 2017-01-01 06:00:00  CALLE DE TOLEDO NUM                           ...
# 1 2017-01-02 21:00:00  CALLE DE MEQUINENZA NUM                       ...
# 2 2017-01-03 19:00:00  CALLE DE LA ESCALINATA NUM                    ...
# 3 2017-01-04 21:00:00  CALLE DE LA CAVA DE SAN MIGUEL NUM            ...
# 4 2017-01-05 08:00:00                            PUENTE DE LOS FRANCESES

# %%
def get_df_norm_header_index(path):
    lst_header = ['num_exp', 'dia', 'hora', 'calle', 'num', 'distrito', 'tipo_accidente', 'meteo', 'vehiculo', 'persona', 'edad', 'sexo', 'lesividad' ]
    df = pd.read_csv(path, encoding='latin_1',sep = ';', names=lst_header)
    df.drop(0, inplace=True)
    df.reset_index(drop=True, inplace=True)
    return df

bici = get_df_norm_header_index('bicicletas/AccidentesBicicletas_2019.csv')

# %%
def create_date(df):
    df['fecha'] = df.dia+' '+df.hora
    df['fecha'] = pd.to_datetime(df['fecha'], dayfirst=True)
    df['fecha'] = df['fecha'].dt.round('H')
    df.drop(['dia', 'hora'], axis=1, inplace = True)
    return df

bici = create_date(bici)

# %%
def create_dir(df):
    df.num.apply(lambda x: x.strip())
    df.num = df.num.apply(lambda x: '-' if x=='0' else x)
    df.loc[(df.num == '-'), 'num']=''
    df['direccion'] = df.calle+' '+df.num
    df.direccion.apply(lambda x: x.strip())
    df.drop(['calle', 'num'], axis=1, inplace = True)
    return df

bici = create_dir(bici)

# %%
def fill_drop(df):
    df.lesividad.fillna('14', inplace=True)
    df.meteo.fillna('Se desconoce', inplace=True)
    df.drop(['sexo', 'vehiculo', 'persona', 'edad', 'num_exp'], axis=1, inplace=True)
    return df

bici = fill_drop(bici)

# %%
def change_accident(values):
    dict_accidente = {
        r'caída':'Caida',
        r'colisión':'Colision',
        r'alcance':'Colision',
        r'atropello':'Imprudencia',
        r'choque':'Imprudencia'}
    for k, v in dict_accidente.items():
        if re.match(k, values.lower()):
            return v
    return 'Otro'

bici.tipo_accidente = bici.tipo_accidente.apply(lambda x: change_accident(x))

# %%
def change_injury(values):
    dict_injury = {
        '01':'Moderada','02':'Moderada',
        '03':'Grave',
        '04':'Fallecido',
        '05':'Leve','06':'Leve','07':'Leve','14':'Leve'}
    return dict_injury[values]


bici.lesividad = bici.lesividad.apply(lambda x: change_injury(str(x)))

# %%
bici = bici[['fecha','meteo', 'tipo_accidente', 'lesividad', 'distrito', 'direccion']]

# %%
bici.head()
# Out:
#                 fecha         meteo tipo_accidente lesividad  \
# 0 2019-01-01 14:00:00     Despejado       Colision  Moderada
# 1 2019-01-02 21:00:00     Despejado       Colision     Grave
# 2 2019-01-03 14:00:00  Se desconoce       Colision      Leve
# 3 2019-01-03 13:00:00     Despejado       Colision      Leve
# 4 2019-01-03 13:00:00     Despejado       Colision      Leve
#
#             distrito                                         direccion
# 0          SALAMANCA      CALL. CASTELLO / CALL. DON RAMON DE LA CRUZ
# 1          HORTALEZA  AVDA. GRAN VIA DE HORTALEZA / GTA. LUIS ROSALES
# 2  VILLA DE VALLECAS                           CALL. FELIPE ALVAREZ 10
# 3  VILLA DE VALLECAS      AVDA. SANTA EUGENIA / CALL. REAL DE ARGANDA
# 4  VILLA DE VALLECAS      AVDA. SANTA EUGENIA / CALL. REAL DE ARGANDA

# %%
bici.meteo.value_counts()
# Out:
# Despejado         703
# Se desconoce       30
# Lluvia débil       27
# Nublado            13
# LLuvia intensa      5
# Granizando          1
# Name: meteo, dtype: int64

# %%
# encoding='cp850'
# encoding='cp1250'

# **
# encoding='latin_1'
# encoding='iso8859_15'

# %%
abr = pd.read_csv('tiempo/Anio2019/abr_meteo19.csv', encoding='latin_1',sep = ';')

# %%
abr.head(20)
# Out:
#     PROVINCIA  MUNICIPIO  ESTACION  MAGNITUD  PUNTO_MUESTREO   ANO  MES  DIA  \
# 0          28         79       102        81  28079102_81_98  2019    4    1
# 1          28         79       102        81  28079102_81_98  2019    4    2
# 2          28         79       102        81  28079102_81_98  2019    4    3
# 3          28         79       102        81  28079102_81_98  2019    4    4
# 4          28         79       102        81  28079102_81_98  2019    4    5
# 5          28         79       102        81  28079102_81_98  2019    4    6
# 6          28         79       102        81  28079102_81_98  2019    4    7
# 7          28         79       102        81  28079102_81_98  2019    4    8
# 8          28         79       102        81  28079102_81_98  2019    4    9
# 9          28         79       102        81  28079102_81_98  2019    4   10
# 10         28         79       102        81  28079102_81_98  2019    4   11
# 11         28         79       102        81  28079102_81_98  2019    4   12
# 12         28         79       102        81  28079102_81_98  2019    4   13
# 13         28         79       102        81  28079102_81_98  2019    4   14
# 14         28         79       102        81  28079102_81_98  2019    4   15
# 15         28         79       102        81  28079102_81_98  2019    4   16
# 16         28         79       102        81  28079102_81_98  2019    4   17
# 17         28         79       102        81  28079102_81_98  2019    4   18
# 18         28         79       102        81  28079102_81_98  2019    4   19
# 19         28         79       102        81  28079102_81_98  2019    4   20
#
#      H01 V01  ...   H20 V20   H21 V21   H22 V22   H23 V23   H24 V24
# 0   1.90   V  ...  1.45   V  0.90   V  0.97   V  1.68   V  1.12   V
# 1   0.40   V  ...  2.48   V  2.05   V  1.88   V  0.95   V  1.10   V
# 2   1.18   V  ...  3.95   V  3.53   V  3.40   V  3.42   V  2.58   V
# 3   2.35   V  ...  3.12   V  2.52   V  2.30   V  2.13   V  1.88   V
# 4   3.02   V  ...  2.88   V  1.43   V  0.93   V  2.18   V  2.58   V
# 5   2.18   V  ...  4.93   V  2.98   V  3.07   V  1.95   V  1.83   V
# 6   2.77   V  ...  1.73   V  1.48   V  0.73   V  0.37   V  0.75   V
# 7   1.18   V  ...  3.95   V  2.82   V  2.50   V  4.33   V  1.30   V
# 8   1.22   V  ...  3.48   V  3.92   V  3.15   V  2.98   V  3.67   V
# 9   1.85   V  ...  2.02   V  1.65   V  1.68   V  1.73   V  1.60   V
# 10  1.87   V  ...  3.37   V  3.03   V  2.37   V  2.32   V  2.73   V
# 11  1.90   V  ...  1.08   V  1.92   V  2.28   V  1.87   V  1.17   V
# 12  1.00   V  ...  1.45   V  1.97   V  2.12   V  1.83   V  1.30   V
# 13  1.60   V  ...  2.10   V  2.38   V  1.98   V  1.77   V  1.13   V
# 14  1.00   V  ...  4.93   V  4.10   V  3.43   V  2.77   V  2.22   V
# 15  1.82   V  ...  2.45   V  2.08   V  1.38   V  1.60   V  3.58   V
# 16  5.13   V  ...  3.95   V  3.03   V  2.32   V  0.93   V  3.53   V
# 17  2.73   V  ...  0.88   V  1.67   V  2.00   V  2.25   V  1.92   V
# 18  1.90   V  ...  0.05   V  0.65   V  1.15   V  0.73   V  0.55   V
# 19  0.75   V  ...  4.12   V  3.03   V  1.75   V  2.82   V  3.78   V
#
# [20 rows x 56 columns]
